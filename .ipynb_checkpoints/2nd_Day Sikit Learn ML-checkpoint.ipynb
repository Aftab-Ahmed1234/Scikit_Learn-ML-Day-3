# %%
import sklearn 
print(sklearn.__version__)
# Out:
# 1.3.0

# %%
import pandas as pd
data = {
    "Study Hours": [2, 4, 6, 8, 10],
    "Attendance": [60, 70, 80, 90, 95],
    "Marks": [50, 60, 75, 90, 98]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Study Hours  Attendance  Marks
# 0            2          60     50
# 1            4          70     60
# 2            6          80     75
# 3            8          90     90
# 4           10          95     98

# %%
x=df[["Study Hours", "Attendance"]]
print(x)
# Out:
#    Study Hours  Attendance
# 0            2          60
# 1            4          70
# 2            6          80
# 3            8          90
# 4           10          95

# %%
y=df[["Marks"]]
print(y)
# Out:
#    Marks
# 0     50
# 1     60
# 2     75
# 3     90
# 4     98
